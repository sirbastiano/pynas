# %% [markdown]
# # Guide to Pynattas (old version)

# %% [markdown]
# NOTE: assuming dependencies already in place. A guide for dependencies will be created on a later date. For now, make sure to have the latest compatible versions of:
# - pytorch and pytorch lightning, torchmetrics and torchvision, cuda
# - tensorflow and tensorboard
# - tqdm
# - datetime
# - matplotlib and numpy
#
# Solve any further incompatibilities as they are raised.

# %% [markdown]
# ## Run the code with current configuration

# %% [markdown]
# NOTE: There are possible combinations of blocks that will crash the run. A saner block selection logic will be added in the future.

# %%
#!pip install tensorboard tensorboardX
#!pip install torch torchvision torchaudio
# Out:
# Collecting tensorboard
#   Downloading tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting tensorboardX
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting absl-py>=0.4 (from tensorboard)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Downloading grpcio-1.65.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard) (1.22.4)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard) (21.3)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard) (70.0.0)
# Requirement already satisfied: six>1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging->tensorboard) (3.1.2)
# Downloading tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 66.6 MB/s eta 0:00:00a 0:00:01
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 31.7 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 42.7 MB/s eta 0:00:00
# Downloading grpcio-1.65.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 176.9 MB/s eta 0:00:00
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 33.2 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Installing collected packages: tensorboard-data-server, markdown, grpcio, absl-py, tensorboardX, tensorboard
# Successfully installed absl-py-2.1.0 grpcio-1.65.5 markdown-3.7 tensorboard-2.17.1 tensorboard-data-server-0.7.2 tensorboardX-2.6.2.2
# Collecting torch
#   Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision
#   Downloading torchvision-0.19.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.0 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.4.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (4.12.1)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (2024.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torchvision) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl (797.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 1.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 172.4 MB/s eta 0:00:0000:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 130.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 126.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 42.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 69.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 42.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 15.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 20.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 28.1 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 12.8 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.19.0-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 38.8 MB/s eta 0:00:00:00:0100:01
# Downloading torchaudio-2.4.0-cp310-cp310-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 111.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 100.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
# ^C
# ERROR: Operation cancelled by user

# %%
#!pip install .
# Out:
# Processing /home/ec2-user/SageMaker/Project-Phisat-2/Phisat (Attempt-BurntArea)/Functional Code-SourceSimulation/PyNA-tta-S
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pynattas==0.0.0) (1.22.4)
# Collecting opencv-python (from pynattas==0.0.0)
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pynattas==0.0.0) (2.2.2)
# Collecting torch (from pynattas==0.0.0)
#   Using cached torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision (from pynattas==0.0.0)
#   Using cached torchvision-0.19.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.0 kB)
# Collecting torchmetrics (from pynattas==0.0.0)
#   Downloading torchmetrics-1.4.1-py3-none-any.whl.metadata (20 kB)
# Collecting pytorch-lightning (from pynattas==0.0.0)
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pynattas==0.0.0) (4.66.4)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pynattas==0.0.0) (3.8.4)
# Requirement already satisfied: seaborn in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pynattas==0.0.0) (0.13.2)
# Collecting rasterio (from pynattas==0.0.0)
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: tifffile in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pynattas==0.0.0) (2024.5.22)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pynattas==0.0.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pynattas==0.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pynattas==0.0.0) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pynattas==0.0.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pynattas==0.0.0) (21.3)
# Requirement already satisfied: pillow>=8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pynattas==0.0.0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pynattas==0.0.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pynattas==0.0.0) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->pynattas==0.0.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->pynattas==0.0.0) (2024.1)
# Requirement already satisfied: PyYAML>=5.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-lightning->pynattas==0.0.0) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->pynattas==0.0.0) (2024.6.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-lightning->pynattas==0.0.0) (4.12.1)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning->pynattas==0.0.0)
#   Downloading lightning_utilities-0.11.6-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch->pynattas==0.0.0) (3.14.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch->pynattas==0.0.0) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch->pynattas==0.0.0) (3.3)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch->pynattas==0.0.0) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->pynattas==0.0.0)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->pynattas==0.0.0)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->pynattas==0.0.0)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->pynattas==0.0.0)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->pynattas==0.0.0)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->pynattas==0.0.0)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->pynattas==0.0.0)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->pynattas==0.0.0)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->pynattas==0.0.0)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->pynattas==0.0.0)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch->pynattas==0.0.0) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch->pynattas==0.0.0) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->pynattas==0.0.0) (12.6.20)
# Collecting affine (from rasterio->pynattas==0.0.0)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rasterio->pynattas==0.0.0) (23.2.0)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rasterio->pynattas==0.0.0) (2024.6.2)
# Requirement already satisfied: click>=4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rasterio->pynattas==0.0.0) (8.1.7)
# Collecting cligj>=0.5 (from rasterio->pynattas==0.0.0)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting snuggs>=1.4.1 (from rasterio->pynattas==0.0.0)
#   Downloading snuggs-1.4.7-py3-none-any.whl.metadata (3.4 kB)
# Collecting click-plugins (from rasterio->pynattas==0.0.0)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rasterio->pynattas==0.0.0) (70.0.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->pynattas==0.0.0) (3.9.5)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->pynattas==0.0.0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jinja2->torch->pynattas==0.0.0) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sympy->torch->pynattas==0.0.0) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->pynattas==0.0.0) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->pynattas==0.0.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->pynattas==0.0.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->pynattas==0.0.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->pynattas==0.0.0) (4.0.3)
# Requirement already satisfied: idna>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->pynattas==0.0.0) (3.7)
# Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 83.4 MB/s eta 0:00:00:00:0100:01
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 125.0 MB/s eta 0:00:00
# Using cached torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl (797.2 MB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)

# %%
import time
from datetime import datetime
from pytorch_lightning.loggers import TensorBoardLogger

# %%
import pynattas as pnas
import torch
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
torch.cuda.empty_cache()

# %%
# %run main.py
# Out:
# Seed set to 42
# *** Network Architecture Search ***
#
# Starting chromosome pool:
# Architecture: Lme3agn1EPa2ELme6arn1EPM2ELne5arn1EPa2ELne3arn1EUf2mnearestES2ELne5arn1EUf2mnearestES1ELme6arn1EUf2mnearestES0ELme3agn1EHSasmEE
# Chromosome: ['Lme3agn1', 'Pa2', 'Lme6arn1', 'PM2', 'Lne5arn1', 'Pa2', 'Lne3arn1', 'Uf2mnearest', 'S2', 'Lne5arn1', 'Uf2mnearest', 'S1', 'Lme6arn1', 'Uf2mnearest', 'S0', 'Lme3agn1', 'HSasm']
# Inside the for loop of ga_optimizer the value of parsed_layers is: [{'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '3', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '3', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '3', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: MBConv, Full Layer: {'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}
# Parsing MBConv
# Parsing GELU
# Parsed MBConv without error
# Parsing layer type in generic_network: AvgPool, Full Layer: {'layer_type': 'AvgPool'}
# Parsing AvgPool
# Parsed AvgPool without error
# Parsing layer type in generic_network: MBConv, Full Layer: {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'ReLU'}
# Parsing MBConv
# Parsing ReLU
# Parsed MBConv without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}
# Parsing MBConvNoRes
# Parsing ReLU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: AvgPool, Full Layer: {'layer_type': 'AvgPool'}
# Parsing AvgPool
# Parsed AvgPool without error
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '3', 'activation': 'ReLU'}
# Parsing MBConvNoRes
# Parsing ReLU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}
# Parsing MBConvNoRes
# Parsing ReLU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: MBConv, Full Layer: {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'ReLU'}
# Parsing MBConv
# Parsing ReLU
# Parsed MBConv without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: MBConv, Full Layer: {'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}
# Parsing MBConv
# Parsing GELU
# Parsed MBConv without error
# Parsing layer type in generic_network: SegmentationHead, Full Layer: {'layer_type': 'SegmentationHead'}
# Parsing SegmentationHead
# Parsed SegmentationHead without error
# Architecture is valid, total parameters: 6920
# Running in not final loop
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W816 21:57:07.489181035 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W816 21:57:07.489294977 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W816 21:57:07.491368476 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W816 21:57:07.500877813 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name    | Type                        | Params | Mode
# ----------------------------------------------------------------
# 0 | model   | GenericNetwork              | 6.9 K  | train
# 1 | loss_fn | CategoricalCrossEntropyLoss | 0      | train
# 2 | mse     | MeanSquaredError            | 0      | train
# ----------------------------------------------------------------
# 6.9 K     Trainable params
# 0         Non-trainable params
# 6.9 K     Total params
# 0.028     Total estimated model params size (MB)
# 110       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# Training: |          | 0/? [00:00<?, ?it/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W816 21:59:17.437524966 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W816 21:59:18.443597765 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W816 21:59:18.512427605 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W816 21:59:18.512481582 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.validate()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_iou          │    0.6067193746566772     │
# │         val_loss          │     0.862496018409729     │
# │          val_mse          │   0.055626463145017624    │
# └───────────────────────────┴───────────────────────────┘
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W816 21:59:23.493116557 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W816 21:59:23.493754045 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W816 21:59:23.524400382 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W816 21:59:23.524461515 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.test()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Testing: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_iou          │    0.6066796779632568     │
# │         test_loss         │    0.8509039282798767     │
# │         test_mse          │    0.04964347556233406    │
# └───────────────────────────┴───────────────────────────┘
# Seed set to 42
# Results are: [{'test_loss': 0.8509039282798767, 'test_mse': 0.04964347556233406, 'test_iou': 0.6066796779632568}]
# MSE value is 0.04964347556233406
# IoU value is 0.6066796779632568
# num_param value is 6920
# Training time: 131.55970859527588
# Fitness: 15.58692118358375
# ********
# chromosome: ['Lme3agn1', 'Pa2', 'Lme6arn1', 'PM2', 'Lne5arn1', 'Pa2', 'Lne3arn1', 'Uf2mnearest', 'S2', 'Lne5arn1', 'Uf2mnearest', 'S1', 'Lme6arn1', 'Uf2mnearest', 'S0', 'Lme3agn1', 'HSasm'], fitness: 15.58692118358375, IoU: 0.6066796779632568, FPS: 428.07446486150184, Model Size: 6920
#
# Architecture: LDd0.50n1EPa2ELbo14k5s1p2arn1EPa2ELeo16k5s1p2arn1EUf2mnearestES1ELbo14k5s1p2arn1EUf2mnearestES0ELDd0.50n1EHSasmEE
# Chromosome: ['LDd0.50n1', 'Pa2', 'Lbo14k5s1p2arn1', 'Pa2', 'Leo16k5s1p2arn1', 'Uf2mnearest', 'S1', 'Lbo14k5s1p2arn1', 'Uf2mnearest', 'S0', 'LDd0.50n1', 'HSasm']
# Inside the for loop of ga_optimizer the value of parsed_layers is: [{'layer_type': 'Dropout', 'dropout_rate': 0.5}, {'layer_type': 'AvgPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 14, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 16, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 14, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'Dropout', 'dropout_rate': 0.5}, {'layer_type': 'SegmentationHead'}]
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'Dropout', 'dropout_rate': 0.5}, {'layer_type': 'AvgPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 14, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 16, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 14, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'Dropout', 'dropout_rate': 0.5}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'Dropout', 'dropout_rate': 0.5}, {'layer_type': 'AvgPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 14, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 16, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 14, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'Dropout', 'dropout_rate': 0.5}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: Dropout, Full Layer: {'layer_type': 'Dropout', 'dropout_rate': 0.5}
# Parsing Dropout
# Parsed Dropout without error
# Parsing layer type in generic_network: AvgPool, Full Layer: {'layer_type': 'AvgPool'}
# Parsing AvgPool
# Parsed AvgPool without error
# Parsing layer type in generic_network: ConvAct, Full Layer: {'layer_type': 'ConvAct', 'out_channels_coefficient': 14, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}
# Parsing ConvAct
# Parsing ReLU
# Parsed ConvAct without error
# Parsing layer type in generic_network: AvgPool, Full Layer: {'layer_type': 'AvgPool'}
# Parsing AvgPool
# Parsed AvgPool without error
# Parsing layer type in generic_network: ConvSE, Full Layer: {'layer_type': 'ConvSE', 'out_channels_coefficient': 16, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}
# Parsing ConvSE
# Parsing ReLU
# Parsed ConvSE without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: ConvAct, Full Layer: {'layer_type': 'ConvAct', 'out_channels_coefficient': 14, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}
# Parsing ConvAct
# Parsing ReLU
# Seed set to 42
# Parsed ConvAct without error
# Skipping architecture, total parameters: 864711232 exceed the threshold of 5000000
# Skipping architecture due to error: The architecture is invalid due to exceeding the parameter limit.
# chromosome: ['LDd0.50n1', 'Pa2', 'Lbo14k5s1p2arn1', 'Pa2', 'Leo16k5s1p2arn1', 'Uf2mnearest', 'S1', 'Lbo14k5s1p2arn1', 'Uf2mnearest', 'S0', 'LDd0.50n1', 'HSasm'], fitness: -inf, IoU: None, FPS: None, Model Size: None
#
# Architecture: Lco12k3s1p1agn1EPM2ELeo07k5s1p2arn1EPM2ELdo04arn1EPa2ELco15k5s1p2arn1EUf2mnearestES2ELdo04arn1EUf2mnearestES1ELeo07k5s1p2arn1EUf2mnearestES0ELco12k3s1p1agn1EHSasmEE
# Chromosome: ['Lco12k3s1p1agn1', 'PM2', 'Leo07k5s1p2arn1', 'PM2', 'Ldo04arn1', 'Pa2', 'Lco15k5s1p2arn1', 'Uf2mnearest', 'S2', 'Ldo04arn1', 'Uf2mnearest', 'S1', 'Leo07k5s1p2arn1', 'Uf2mnearest', 'S0', 'Lco12k3s1p1agn1', 'HSasm']
# Inside the for loop of ga_optimizer the value of parsed_layers is: [{'layer_type': 'ConvBnAct', 'out_channels_coefficient': 12, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 7, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 4, 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 4, 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 7, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 12, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'ConvBnAct', 'out_channels_coefficient': 12, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 7, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 4, 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 4, 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 7, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 12, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'ConvBnAct', 'out_channels_coefficient': 12, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 7, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 4, 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 4, 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 7, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 12, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: ConvBnAct, Full Layer: {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 12, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}
# Parsing ConvBnAct
# Parsing GELU
# Parsed ConvBnAct without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: ConvSE, Full Layer: {'layer_type': 'ConvSE', 'out_channels_coefficient': 7, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}
# Parsing ConvSE
# Parsing ReLU
# Parsed ConvSE without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: DenseNetBlock, Full Layer: {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 4, 'activation': 'ReLU'}
# Parsing DenseNetBlock
# Parsing ReLU
# Seed set to 42
# Parsed DenseNetBlock without error
# Skipping architecture, total parameters: 13734756 exceed the threshold of 5000000
# Skipping architecture due to error: The architecture is invalid due to exceeding the parameter limit.
# chromosome: ['Lco12k3s1p1agn1', 'PM2', 'Leo07k5s1p2arn1', 'PM2', 'Ldo04arn1', 'Pa2', 'Lco15k5s1p2arn1', 'Uf2mnearest', 'S2', 'Ldo04arn1', 'Uf2mnearest', 'S1', 'Leo07k5s1p2arn1', 'Uf2mnearest', 'S0', 'Lco12k3s1p1agn1', 'HSasm'], fitness: -inf, IoU: None, FPS: None, Model Size: None
#
# Architecture: LRr3agn1EPa2ELdo16arn1EPM2ELdo16agn1EUf2mnearestES1ELdo16arn1EUf2mnearestES0ELRr3agn1EHSasmEE
# Chromosome: ['LRr3agn1', 'Pa2', 'Ldo16arn1', 'PM2', 'Ldo16agn1', 'Uf2mnearest', 'S1', 'Ldo16arn1', 'Uf2mnearest', 'S0', 'LRr3agn1', 'HSasm']
# Inside the for loop of ga_optimizer the value of parsed_layers is: [{'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: ResNetBlock, Full Layer: {'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}
# Parsing ResNetBlock
# Parsing GELU
# Parsed ResNetBlock without error
# Parsing layer type in generic_network: AvgPool, Full Layer: {'layer_type': 'AvgPool'}
# Parsing AvgPool
# Parsed AvgPool without error
# Parsing layer type in generic_network: DenseNetBlock, Full Layer: {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'ReLU'}
# Parsing DenseNetBlock
# Parsing ReLU
# Parsed DenseNetBlock without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: DenseNetBlock, Full Layer: {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'GELU'}
# Parsing DenseNetBlock
# Parsing GELU
# Parsed DenseNetBlock without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: DenseNetBlock, Full Layer: {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'ReLU'}
# Parsing DenseNetBlock
# Parsing ReLU
# Seed set to 42
# Parsed DenseNetBlock without error
# Skipping architecture, total parameters: 591409148 exceed the threshold of 5000000
# Skipping architecture due to error: The architecture is invalid due to exceeding the parameter limit.
# chromosome: ['LRr3agn1', 'Pa2', 'Ldo16arn1', 'PM2', 'Ldo16agn1', 'Uf2mnearest', 'S1', 'Ldo16arn1', 'Uf2mnearest', 'S0', 'LRr3agn1', 'HSasm'], fitness: -inf, IoU: None, FPS: None, Model Size: None
#
# Architecture: LDd0.26n1EPM2ELbo15k5s1p2arn1EPM2ELbo10k5s1p2arn1EPM2ELbo10k5s1p2agn1EUf2mnearestES2ELbo10k5s1p2arn1EUf2mnearestES1ELbo15k5s1p2arn1EUf2mnearestES0ELDd0.26n1EHSasmEE
# Chromosome: ['LDd0.26n1', 'PM2', 'Lbo15k5s1p2arn1', 'PM2', 'Lbo10k5s1p2arn1', 'PM2', 'Lbo10k5s1p2agn1', 'Uf2mnearest', 'S2', 'Lbo10k5s1p2arn1', 'Uf2mnearest', 'S1', 'Lbo15k5s1p2arn1', 'Uf2mnearest', 'S0', 'LDd0.26n1', 'HSasm']
# Inside the for loop of ga_optimizer the value of parsed_layers is: [{'layer_type': 'Dropout', 'dropout_rate': 0.26}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'Dropout', 'dropout_rate': 0.26}, {'layer_type': 'SegmentationHead'}]
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'Dropout', 'dropout_rate': 0.26}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'Dropout', 'dropout_rate': 0.26}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'Dropout', 'dropout_rate': 0.26}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'Dropout', 'dropout_rate': 0.26}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: Dropout, Full Layer: {'layer_type': 'Dropout', 'dropout_rate': 0.26}
# Parsing Dropout
# Parsed Dropout without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: ConvAct, Full Layer: {'layer_type': 'ConvAct', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}
# Parsing ConvAct
# Parsing ReLU
# Parsed ConvAct without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: ConvAct, Full Layer: {'layer_type': 'ConvAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}
# Parsing ConvAct
# Parsing ReLU
# Parsed ConvAct without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: ConvAct, Full Layer: {'layer_type': 'ConvAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'GELU'}
# Parsing ConvAct
# Parsing GELU
# Seed set to 42
# Parsed ConvAct without error
# Skipping architecture, total parameters: 278411280 exceed the threshold of 5000000
# Skipping architecture due to error: The architecture is invalid due to exceeding the parameter limit.
# chromosome: ['LDd0.26n1', 'PM2', 'Lbo15k5s1p2arn1', 'PM2', 'Lbo10k5s1p2arn1', 'PM2', 'Lbo10k5s1p2agn1', 'Uf2mnearest', 'S2', 'Lbo10k5s1p2arn1', 'Uf2mnearest', 'S1', 'Lbo15k5s1p2arn1', 'Uf2mnearest', 'S0', 'LDd0.26n1', 'HSasm'], fitness: -inf, IoU: None, FPS: None, Model Size: None
#
# Architecture: Lco05k3s1p1arn1EPM2ELdo16agn1EPM2ELne5agn1EPM2ELco06k5s1p2agn1EUf2mnearestES2ELne5agn1EUf2mnearestES1ELdo16agn1EUf2mnearestES0ELco05k3s1p1arn1EHSasmEE
# Chromosome: ['Lco05k3s1p1arn1', 'PM2', 'Ldo16agn1', 'PM2', 'Lne5agn1', 'PM2', 'Lco06k5s1p2agn1', 'Uf2mnearest', 'S2', 'Lne5agn1', 'Uf2mnearest', 'S1', 'Ldo16agn1', 'Uf2mnearest', 'S0', 'Lco05k3s1p1arn1', 'HSasm']
# Inside the for loop of ga_optimizer the value of parsed_layers is: [{'layer_type': 'ConvBnAct', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 6, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'ConvBnAct', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 6, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'ConvBnAct', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 6, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: ConvBnAct, Full Layer: {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}
# Parsing ConvBnAct
# Parsing ReLU
# Parsed ConvBnAct without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: DenseNetBlock, Full Layer: {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 16, 'activation': 'GELU'}
# Parsing DenseNetBlock
# Parsing GELU
# Parsed DenseNetBlock without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'GELU'}
# Parsing MBConvNoRes
# Parsing GELU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: ConvBnAct, Full Layer: {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 6, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'GELU'}
# Parsing ConvBnAct
# Parsing GELU
# Seed set to 42
# Parsed ConvBnAct without error
# Skipping architecture, total parameters: 56880460 exceed the threshold of 5000000
# Skipping architecture due to error: The architecture is invalid due to exceeding the parameter limit.
# chromosome: ['Lco05k3s1p1arn1', 'PM2', 'Ldo16agn1', 'PM2', 'Lne5agn1', 'PM2', 'Lco06k5s1p2agn1', 'Uf2mnearest', 'S2', 'Lne5agn1', 'Uf2mnearest', 'S1', 'Ldo16agn1', 'Uf2mnearest', 'S0', 'Lco05k3s1p1arn1', 'HSasm'], fitness: -inf, IoU: None, FPS: None, Model Size: None
#
# Architecture: Leo15k5s1p2arn1EPM2ELco10k5s1p2arn1EUf2mnearestES0ELeo15k5s1p2arn1EHSasmEE
# Chromosome: ['Leo15k5s1p2arn1', 'PM2', 'Lco10k5s1p2arn1', 'Uf2mnearest', 'S0', 'Leo15k5s1p2arn1', 'HSasm']
# Inside the for loop of ga_optimizer the value of parsed_layers is: [{'layer_type': 'ConvSE', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'ConvSE', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'ConvSE', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: ConvSE, Full Layer: {'layer_type': 'ConvSE', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}
# Parsing ConvSE
# Parsing ReLU
# Parsed ConvSE without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: ConvBnAct, Full Layer: {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 10, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}
# Parsing ConvBnAct
# Parsing ReLU
# Parsed ConvBnAct without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: ConvSE, Full Layer: {'layer_type': 'ConvSE', 'out_channels_coefficient': 15, 'kernel_size': '5', 'stride': '1', 'padding': '2', 'activation': 'ReLU'}
# Parsing ConvSE
# Parsing ReLU
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Parsed ConvSE without error
# Skipping architecture, total parameters: 447260100 exceed the threshold of 5000000
# Skipping architecture due to error: The architecture is invalid due to exceeding the parameter limit.
# chromosome: ['Leo15k5s1p2arn1', 'PM2', 'Lco10k5s1p2arn1', 'Uf2mnearest', 'S0', 'Leo15k5s1p2arn1', 'HSasm'], fitness: -inf, IoU: None, FPS: None, Model Size: None
#
# Architecture: Lbo05k3s1p1arn1EPa2ELme4agn1EPM2ELne5agn1EUf2mnearestES1ELme4agn1EUf2mnearestES0ELbo05k3s1p1arn1EHSasmEE
# Chromosome: ['Lbo05k3s1p1arn1', 'Pa2', 'Lme4agn1', 'PM2', 'Lne5agn1', 'Uf2mnearest', 'S1', 'Lme4agn1', 'Uf2mnearest', 'S0', 'Lbo05k3s1p1arn1', 'HSasm']
# Inside the for loop of ga_optimizer the value of parsed_layers is: [{'layer_type': 'ConvAct', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'MBConv', 'expansion_factor': '4', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '4', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'ConvAct', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'MBConv', 'expansion_factor': '4', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '4', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# ...
# MSE value is 0.06327164173126221
# IoU value is 0.7040719985961914
# num_param value is 610197
# Training time: 974.5915670394897
# Fitness: 15.835457348471191
# ********
# chromosome: ['Lme3arn1', 'PM2', 'Ldo06arn1', 'Pa2', 'Lne3arn1', 'Uf2mnearest', 'S1', 'LRr3agn1', 'Uf2mnearest', 'S0', 'Lco04k5s1p2agn1', 'HSasm'], fitness: 15.835457348471191, IoU: 0.7040719985961914, FPS: 152.20627121681562, Model Size: 610197
#
# THE LAST GENERATION (5):
# For generation 5, the best fitness of the population is 16.93363313358497.
# The best historical fitness is 17.64535144181185,with the most fit individual having the following genes: ['Lme3agn1', 'Pa2', 'Ldo05agn1', 'PM2', 'Lne5arn1', 'Pa2', 'Lne3arn1', 'Uf2mnearest', 'S2', 'Lne5arn1', 'Uf2mnearest', 'S1', 'Lme6arn1', 'Uf2mnearest', 'S0', 'Lme3agn1', 'HSasm'].
# Text file saved: ./logs/GA_logs/GA_generation_5.txt
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# NAS completed. Best architecture: Lme3agn1EPa2ELdo05agn1EPM2ELne5arn1EPa2ELne3arn1EUf2mnearestES2ELne5arn1EUf2mnearestES1ELme6arn1EUf2mnearestES0ELme3agn1EHSasmEE
# Process finished in 12023.753573179245 s. Starting final run...
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 5, 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '3', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
#
# FINAL RUN ON OPTIMIZED ARCHITECTURE
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 5, 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '3', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: MBConv, Full Layer: {'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}
# Parsing MBConv
# Parsing GELU
# Parsed MBConv without error
# Parsing layer type in generic_network: AvgPool, Full Layer: {'layer_type': 'AvgPool'}
# Parsing AvgPool
# Parsed AvgPool without error
# Parsing layer type in generic_network: DenseNetBlock, Full Layer: {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 5, 'activation': 'GELU'}
# Parsing DenseNetBlock
# Parsing GELU
# Parsed DenseNetBlock without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}
# Parsing MBConvNoRes
# Parsing ReLU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: AvgPool, Full Layer: {'layer_type': 'AvgPool'}
# Parsing AvgPool
# Parsed AvgPool without error
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '3', 'activation': 'ReLU'}
# Parsing MBConvNoRes
# Parsing ReLU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}
# Parsing MBConvNoRes
# Parsing ReLU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: MBConv, Full Layer: {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'ReLU'}
# Parsing MBConv
# Parsing ReLU
# Parsed MBConv without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: MBConv, Full Layer: {'layer_type': 'MBConv', 'expansion_factor': '3', 'activation': 'GELU'}
# Parsing MBConv
# Parsing GELU
# Parsed MBConv without error
# Parsing layer type in generic_network: SegmentationHead, Full Layer: {'layer_type': 'SegmentationHead'}
# Parsing SegmentationHead
# Parsed SegmentationHead without error
# Architecture is valid, total parameters: 111080
# Running in final loop
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W817 01:17:30.711039472 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W817 01:17:30.727539427 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W817 01:17:30.728944352 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W817 01:17:30.730511226 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name    | Type                        | Params | Mode
# ----------------------------------------------------------------
# 0 | model   | GenericNetwork              | 111 K  | train
# 1 | loss_fn | CategoricalCrossEntropyLoss | 0      | train
# 2 | mse     | MeanSquaredError            | 0      | train
# ----------------------------------------------------------------
# 111 K     Trainable params
# 0         Non-trainable params
# 111 K     Total params
# 0.444     Total estimated model params size (MB)
# 102       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W817 01:25:21.622121564 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W817 01:25:21.632320371 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W817 01:25:21.660399680 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W817 01:25:21.660421073 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.validate()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_iou          │    0.7567247152328491     │
# │         val_loss          │    0.8645886182785034     │
# │          val_mse          │    0.05740900710225105    │
# └───────────────────────────┴───────────────────────────┘
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W817 01:25:28.914088069 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W817 01:25:28.914565447 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W817 01:25:28.956390479 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W817 01:25:28.956410051 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.test()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Testing: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_iou          │    0.7519435286521912     │
# │         test_loss         │    0.8634743094444275     │
# │         test_mse          │    0.05661889165639877    │
# └───────────────────────────┴───────────────────────────┘
# MSE value is 0.05661889165639877
# IoU value is 0.7519435286521912
# num_param value is 111080
# FINAL RUN COMPLETED:
# Training time: 471.1396746635437
# Fitness: 16.872505586090746
# ********
#
# Final run text file saved: ./logs/tb_logs/checkpoints/Optimized_Architecture_Final_Run_2024-08-17_01-17-29.txt

# %% [markdown]
# ## GUIDE TO CONFIG.INI

# %% [markdown]
# NOTE: most sanity checks are still missing. Be careful please.

# %% [markdown]
# - In the [Mode] section, select the desired mode for pynattas. If both are true, nas will be done first, then ht will be done on the winning architecture of nas. If only ht is true, then tuning will be done on the architecture written in architecture_code under the [NAS] section.
# - max_layers in [NAS] section refers to the maximum size of the chromosomes (aka, maximum number of convolutions-type layers).
# - In the [GA] section, change the parameters for NAS search.
# - In the [Computation] section, be careful about the num_workers value. Currently set to 1 for safety when testing parallelization. In computation, also change the accellerator to either "cpu" or "gpu".

# %% [markdown]
# ## GUIDE TO PARALLELIZATION (currently broken)

# %% [markdown]
# NOTE: Mostly untested.
# - In main.py, change line 54 ("nas_result = pnas.optimizers.ga.ga_optimizer(") to:
#     - nas_result = pnas.optimizers.ga_concurrent.ga_optimizer(" for nas parallelization using a ThreadPoolExecutor
#     - nas_result = pnas.optimizers.ga_concurrent_pp.ga_optimizer(" for nas parallelization using a ProcessPoolExecutor
#
# Currently, it looks like there are issues with ProcessPoolExecutor. Regardless, be careful when selecting num_workers in the config.ini when testing these.

# %% [markdown]
# ## TO ADD NEW BLOCKS

# %% [markdown]
# - in pynattas.blocks add the new block to the related .py file depending on type.
# - in config.ini add the new block as a section with all related parameters. Use "default_" for default values that are used during NAS, and "min_" and "max_" for range values to be used during tuning. Also, update the commented vocabulary at the start for clarity purposes.
# - in pynattas.configuration.vocabulary, update relative vocabularies.
# - in pynattas.classes.generic_network, add the layer construction to the list making sure that the current_layers, current_height, and current_width is calculated correctly.

# %% [markdown]
# ## TO WORK ON NEW DATASET

# %% [markdown]
# - Add dataset to the "data" folder
# - Add compatible datamodule to the "datasets" folder
# - in pynattas.functions.fitness, import the desired datamodule. Also, around line 59, update the datahandling to be compatible with your datamodule. For the ClassificationHead, Make sure the data is resized to 256x256 sized HxW images, that the number of channels passed to the model is correct.
# - change config.ini in the [Dataset] section. "data_path" should point to the dataset, "csv_path" is for a .csv for labels if required. If it's not required, imput None

# %% [markdown]
# ## GUIDE TO LOGS

# %% [markdown]
# Logs are stored in the "logs" folder and in the "lightning_logs" folder. In "logs", you will find:
# - logs about NAS iterations and results in the GA_logs subfolder
# - logs about HT iterations and results in either the GWO_logs or PSO_logs subfolder depending on the selected HT algorithm
# - logs about the final run comprised of the saved checkpoint .ckpt file in the "tb_logs" subfolder, together with all the confusion matrixes generated.

# %% [markdown]
# ## INFERENCE (Coming soon...)
