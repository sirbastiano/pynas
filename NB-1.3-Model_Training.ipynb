# %% [markdown]
# # Guide to Pynattas (old version)

# %% [markdown]
# NOTE: assuming dependencies already in place. A guide for dependencies will be created on a later date. For now, make sure to have the latest compatible versions of:
# - pytorch and pytorch lightning, torchmetrics and torchvision, cuda
# - tensorflow and tensorboard
# - tqdm
# - datetime
# - matplotlib and numpy
#
# Solve any further incompatibilities as they are raised.

# %% [markdown]
# ## Run the code with current configuration

# %% [markdown]
# NOTE: There are possible combinations of blocks that will crash the run. A saner block selection logic will be added in the future.

# %%
#!pip install setuptools==67.0.0

# %%
#!pip install tensorboard
#!pip install tensorboardX

# %%
#!pip install .

# %%
import time
from datetime import datetime
from pytorch_lightning.loggers import TensorBoardLogger

# %%
import pynattas as pnas
import torch
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
torch.cuda.empty_cache()

# %%
# %run main.py
# Out:
# *** Network Architecture Search ***
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Starting chromosome pool:
# *** GENERATION 0 ***
# Architecture: Lne5arn1EPa2ELdo06arn1EUf2mnearestES0ELne5arn1EHSEE
# Chromosome: ['Lne5arn1', 'Pa2', 'Ldo06arn1', 'Uf2mnearest', 'S0', 'Lne5arn1', 'HS']
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 6, 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 6, 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}
# Parsing MBConvNoRes
# Parsing ReLU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: AvgPool, Full Layer: {'layer_type': 'AvgPool'}
# Parsing AvgPool
# Parsed AvgPool without error
# Parsing layer type in generic_network: DenseNetBlock, Full Layer: {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 6, 'activation': 'ReLU'}
# Parsing DenseNetBlock
# Parsing ReLU
# Parsed DenseNetBlock without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '5', 'activation': 'ReLU'}
# Parsing MBConvNoRes
# Parsing ReLU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: SegmentationHead, Full Layer: {'layer_type': 'SegmentationHead'}
# Parsing SegmentationHead
# Parsed SegmentationHead without error
# Architecture is valid, total parameters: 53428
# Running in not final loop
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W827 21:15:53.130596032 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:15:53.147405576 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:15:53.154206235 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:15:53.156740761 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | GenericNetwork   | 53.4 K | train
# 1 | loss_fn | FocalLoss        | 0      | train
# 2 | mse     | MeanSquaredError | 0      | train
# -----------------------------------------------------
# 53.4 K    Trainable params
# 0         Non-trainable params
# 53.4 K    Total params
# 0.214     Total estimated model params size (MB)
# 43        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# Training: |          | 0/? [00:00<?, ?it/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W827 21:22:42.134473291 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:22:42.134493614 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:22:42.192519635 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:22:42.192519695 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.validate()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_iou          │    0.5472728610038757     │
# │         val_loss          │    0.35742852091789246    │
# │          val_mse          │    0.06867583096027374    │
# └───────────────────────────┴───────────────────────────┘
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W827 21:22:50.856607956 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:22:50.858502566 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:22:50.932436108 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:22:50.932449723 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.test()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Testing: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_iou          │    0.5419926643371582     │
# │         test_loss         │    0.3588126003742218     │
# │         test_mse          │    0.06871706992387772    │
# └───────────────────────────┴───────────────────────────┘
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Results are: [{'test_loss': 0.3588126003742218, 'test_mse': 0.06871706992387772, 'test_iou': 0.5419926643371582}]
# MSE value is 0.06871706992387772
# IoU value is 0.5419926643371582
# num_param value is 53428
# Training time: 409.6069371700287
# Fitness: 14.723512095689955
# ********
#
#
#
#
#
# chromosome: ['Lne5arn1', 'Pa2', 'Ldo06arn1', 'Uf2mnearest', 'S0', 'Lne5arn1', 'HS'], fitness: 14.723512095689955, IoU: 0.5419926643371582, FPS: 287.89533834173596, Model Size: 53428
# Architecture: Lne6arn1EPa2ELdo05arn1EUf2mnearestES0ELne6arn1EHSEE
# Chromosome: ['Lne6arn1', 'Pa2', 'Ldo05arn1', 'Uf2mnearest', 'S0', 'Lne6arn1', 'HS']
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 5, 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 5, 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'ReLU'}
# Parsing MBConvNoRes
# Parsing ReLU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: AvgPool, Full Layer: {'layer_type': 'AvgPool'}
# Parsing AvgPool
# Parsed AvgPool without error
# Parsing layer type in generic_network: DenseNetBlock, Full Layer: {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 5, 'activation': 'ReLU'}
# Parsing DenseNetBlock
# Parsing ReLU
# Parsed DenseNetBlock without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'ReLU'}
# Parsing MBConvNoRes
# Parsing ReLU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: SegmentationHead, Full Layer: {'layer_type': 'SegmentationHead'}
# Parsing SegmentationHead
# Parsed SegmentationHead without error
# Architecture is valid, total parameters: 44657
# Running in not final loop
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W827 21:22:57.896634594 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:22:57.907638592 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:22:57.964441867 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:22:57.964471643 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | GenericNetwork   | 44.7 K | train
# 1 | loss_fn | FocalLoss        | 0      | train
# 2 | mse     | MeanSquaredError | 0      | train
# -----------------------------------------------------
# 44.7 K    Trainable params
# 0         Non-trainable params
# 44.7 K    Total params
# 0.179     Total estimated model params size (MB)
# 43        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# Training: |          | 0/? [00:00<?, ?it/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W827 21:28:34.344422934 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:28:34.349227287 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:28:34.372352915 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:28:34.374634110 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.validate()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_iou          │    0.6529226303100586     │
# │         val_loss          │    0.39353513717651367    │
# │          val_mse          │    0.08412188291549683    │
# └───────────────────────────┴───────────────────────────┘
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W827 21:28:41.008150814 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:28:41.011094898 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:28:41.019876606 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:28:41.020506010 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.test()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Testing: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_iou          │    0.6535127758979797     │
# │         test_loss         │     0.380437970161438     │
# │         test_mse          │    0.07690410315990448    │
# └───────────────────────────┴───────────────────────────┘
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Results are: [{'test_loss': 0.380437970161438, 'test_mse': 0.07690410315990448, 'test_iou': 0.6535127758979797}]
# MSE value is 0.07690410315990448
# IoU value is 0.6535127758979797
# num_param value is 44657
# Training time: 336.45058965682983
# Fitness: 15.776348647881429
# ********
#
#
#
#
#
# chromosome: ['Lne6arn1', 'Pa2', 'Ldo05arn1', 'Uf2mnearest', 'S0', 'Lne6arn1', 'HS'], fitness: 15.776348647881429, IoU: 0.6535127758979797, FPS: 288.7910477958953, Model Size: 44657
# Architecture: LRr3agn1EPa2ELco11k3s1p1agn1EPM2ELRr4agn1EUf2mnearestES1ELco11k3s1p1agn1EUf2mnearestES0ELRr3agn1EHSEE
# Chromosome: ['LRr3agn1', 'Pa2', 'Lco11k3s1p1agn1', 'PM2', 'LRr4agn1', 'Uf2mnearest', 'S1', 'Lco11k3s1p1agn1', 'Uf2mnearest', 'S0', 'LRr3agn1', 'HS']
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 11, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ResNetBlock', 'reduction_factor': '4', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 11, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 11, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ResNetBlock', 'reduction_factor': '4', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 11, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: ResNetBlock, Full Layer: {'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}
# Parsing ResNetBlock
# Parsing GELU
# Parsed ResNetBlock without error
# Parsing layer type in generic_network: AvgPool, Full Layer: {'layer_type': 'AvgPool'}
# Parsing AvgPool
# Parsed AvgPool without error
# Parsing layer type in generic_network: ConvBnAct, Full Layer: {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 11, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}
# Parsing ConvBnAct
# Parsing GELU
# Parsed ConvBnAct without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: ResNetBlock, Full Layer: {'layer_type': 'ResNetBlock', 'reduction_factor': '4', 'activation': 'GELU'}
# Parsing ResNetBlock
# Parsing GELU
# Parsed ResNetBlock without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: ConvBnAct, Full Layer: {'layer_type': 'ConvBnAct', 'out_channels_coefficient': 11, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}
# Parsing ConvBnAct
# Parsing GELU
# Parsed ConvBnAct without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: ResNetBlock, Full Layer: {'layer_type': 'ResNetBlock', 'reduction_factor': '3', 'activation': 'GELU'}
# Parsing ResNetBlock
# Parsing GELU
# Parsed ResNetBlock without error
# Parsing layer type in generic_network: SegmentationHead, Full Layer: {'layer_type': 'SegmentationHead'}
# Parsing SegmentationHead
# Parsed SegmentationHead without error
# Architecture is valid, total parameters: 7824014
# Running in not final loop
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W827 21:28:48.071646204 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:28:48.078751101 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:28:48.095361963 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 21:28:48.098387808 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | GenericNetwork   | 7.8 M  | train
# 1 | loss_fn | FocalLoss        | 0      | train
# 2 | mse     | MeanSquaredError | 0      | train
# -----------------------------------------------------
# 7.8 M     Trainable params
# 0         Non-trainable params
# 7.8 M     Total params
# 31.296    Total estimated model params size (MB)
# 68        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# Training: |          | 0/? [00:00<?, ?it/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W827 22:46:33.340555149 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 22:46:33.371114845 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 22:46:33.372245476 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 22:46:33.375962441 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.validate()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_iou          │    0.4912008047103882     │
# │         val_loss          │    0.45689529180526733    │
# │          val_mse          │    0.6413834691047668     │
# └───────────────────────────┴───────────────────────────┘
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W827 22:48:24.233696629 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 22:48:24.235631011 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 22:48:24.247397031 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W827 22:48:24.251268926 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.test()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Testing: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_iou          │    0.48631685972213745    │
# │         test_loss         │    0.4522564709186554     │
# │         test_mse          │    0.5621872544288635     │
# └───────────────────────────┴───────────────────────────┘
# Seed set to 42
# Results are: [{'test_loss': 0.4522564709186554, 'test_mse': 0.5621872544288635, 'test_iou': 0.48631685972213745}]
# MSE value is 0.5621872544288635
# IoU value is 0.48631685972213745
# num_param value is 7824014
# Training time: 4664.25079870224
# Fitness: 3.440435859534583
# ********
#
#
#
#
#
# chromosome: ['LRr3agn1', 'Pa2', 'Lco11k3s1p1agn1', 'PM2', 'LRr4agn1', 'Uf2mnearest', 'S1', 'Lco11k3s1p1agn1', 'Uf2mnearest', 'S0', 'LRr3agn1', 'HS'], fitness: 3.440435859534583, IoU: 0.48631685972213745, FPS: 20.754698672400735, Model Size: 7824014
# Architecture: Ldo11agn1EPM2ELeo05k3s1p1arn1EPM2ELRr2agn1EUf2mnearestES1ELeo05k3s1p1arn1EUf2mnearestES0ELdo11agn1EHSEE
# Chromosome: ['Ldo11agn1', 'PM2', 'Leo05k3s1p1arn1', 'PM2', 'LRr2agn1', 'Uf2mnearest', 'S1', 'Leo05k3s1p1arn1', 'Uf2mnearest', 'S0', 'Ldo11agn1', 'HS']
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 11, 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ResNetBlock', 'reduction_factor': '2', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 11, 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 11, 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ResNetBlock', 'reduction_factor': '2', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 11, 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: DenseNetBlock, Full Layer: {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 11, 'activation': 'GELU'}
# Parsing DenseNetBlock
# Parsing GELU
# Parsed DenseNetBlock without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: ConvSE, Full Layer: {'layer_type': 'ConvSE', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}
# Parsing ConvSE
# Parsing ReLU
# Parsed ConvSE without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: ResNetBlock, Full Layer: {'layer_type': 'ResNetBlock', 'reduction_factor': '2', 'activation': 'GELU'}
# Parsing ResNetBlock
# Parsing GELU
# Parsed ResNetBlock without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: ConvSE, Full Layer: {'layer_type': 'ConvSE', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}
# Parsing ConvSE
# Parsing ReLU
# Parsed ConvSE without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: DenseNetBlock, Full Layer: {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 11, 'activation': 'GELU'}
# Parsing DenseNetBlock
# Parsing GELU
# Seed set to 42
# Parsed DenseNetBlock without error
# Skipping architecture, total parameters: 445646677 exceed the threshold of 10000000
# Skipping architecture due to error: The architecture is invalid due to exceeding the parameter limit.
# chromosome: ['Ldo11agn1', 'PM2', 'Leo05k3s1p1arn1', 'PM2', 'LRr2agn1', 'Uf2mnearest', 'S1', 'Leo05k3s1p1arn1', 'Uf2mnearest', 'S0', 'Ldo11agn1', 'HS'], fitness: -inf, IoU: None, FPS: None, Model Size: None
# Architecture: Lme6agn1EPM2ELeo12k3s1p1arn1EPM2ELbo09k3s1p1agn1EPM2ELeo05k3s1p1arn1EUf2mnearestES2ELbo09k3s1p1agn1EUf2mnearestES1ELeo12k3s1p1arn1EUf2mnearestES0ELme6agn1EHSEE
# Chromosome: ['Lme6agn1', 'PM2', 'Leo12k3s1p1arn1', 'PM2', 'Lbo09k3s1p1agn1', 'PM2', 'Leo05k3s1p1arn1', 'Uf2mnearest', 'S2', 'Lbo09k3s1p1agn1', 'Uf2mnearest', 'S1', 'Leo12k3s1p1arn1', 'Uf2mnearest', 'S0', 'Lme6agn1', 'HS']
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 12, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 9, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 9, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 12, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 12, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 9, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvAct', 'out_channels_coefficient': 9, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'ConvSE', 'out_channels_coefficient': 12, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: MBConv, Full Layer: {'layer_type': 'MBConv', 'expansion_factor': '6', 'activation': 'GELU'}
# Parsing MBConv
# Parsing GELU
# Parsed MBConv without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: ConvSE, Full Layer: {'layer_type': 'ConvSE', 'out_channels_coefficient': 12, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}
# Parsing ConvSE
# Parsing ReLU
# Parsed ConvSE without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: ConvAct, Full Layer: {'layer_type': 'ConvAct', 'out_channels_coefficient': 9, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'GELU'}
# Parsing ConvAct
# Parsing GELU
# Parsed ConvAct without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: ConvSE, Full Layer: {'layer_type': 'ConvSE', 'out_channels_coefficient': 5, 'kernel_size': '3', 'stride': '1', 'padding': '1', 'activation': 'ReLU'}
# Parsing ConvSE
# Parsing ReLU
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Parsed ConvSE without error
# Skipping architecture, total parameters: 28094535 exceed the threshold of 10000000
# Skipping architecture due to error: The architecture is invalid due to exceeding the parameter limit.
# chromosome: ['Lme6agn1', 'PM2', 'Leo12k3s1p1arn1', 'PM2', 'Lbo09k3s1p1agn1', 'PM2', 'Leo05k3s1p1arn1', 'Uf2mnearest', 'S2', 'Lbo09k3s1p1agn1', 'Uf2mnearest', 'S1', 'Leo12k3s1p1arn1', 'Uf2mnearest', 'S0', 'Lme6agn1', 'HS'], fitness: -inf, IoU: None, FPS: None, Model Size: None
# Architecture: Ldo06agn1EPa2ELne6agn1EUf2mnearestES0ELdo06agn1EHSEE
# Chromosome: ['Ldo06agn1', 'Pa2', 'Lne6agn1', 'Uf2mnearest', 'S0', 'Ldo06agn1', 'HS']
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 6, 'activation': 'GELU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 6, 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 6, 'activation': 'GELU'}, {'layer_type': 'AvgPool'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'GELU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 6, 'activation': 'GELU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: DenseNetBlock, Full Layer: {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 6, 'activation': 'GELU'}
# Parsing DenseNetBlock
# ...
# [W829 01:47:03.047560982 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W829 01:47:03.050440702 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W829 01:47:03.050670527 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.test()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Testing: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_iou          │    0.6815155744552612     │
# │         test_loss         │    0.5069140195846558     │
# │         test_mse          │    0.1536262333393097     │
# └───────────────────────────┴───────────────────────────┘
# Results are: [{'test_loss': 0.5069140195846558, 'test_mse': 0.1536262333393097, 'test_iou': 0.6815155744552612}]
# MSE value is 0.1536262333393097
# IoU value is 0.6815155744552612
# num_param value is 3938512
# Training time: 2337.665572166443
# Fitness: 11.544962573480245
# ********
#
#
#
#
#
# chromosome: ['Lco09k3s1p1agn1', 'Pa2', 'Lco10k3s1p1agn1', 'Uf2mnearest', 'S1', 'LDd0.31n1', 'HS'], fitness: 11.544962573480245, IoU: 0.6815155744552612, FPS: 43.8679124536699, Model Size: 3938512
# THE LAST GENERATION (10):
# For generation 10, the best fitness of the population is 17.004135408954063.
# The best historical fitness is 17.004135408954063,with the most fit individual having the following genes: ['Lne6arn1', 'PM2', 'Ldo06arn1', 'Uf2mnearest', 'S0', 'Lne6arn1', 'HS'].
# Text file saved: ./logs/GA_logs/GA_generation_10.txt
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# NAS completed. Best architecture: Lne6arn1EPM2ELdo06arn1EUf2mnearestES0ELne6arn1EHSEE
# Process finished in 102717.72710061073 s. Starting final run...
# -----------The batch size of the data to be loaded in the model is: 4-----------
# Task type in fitness is: segmentation
#
#
# ***
#
# [{'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 6, 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# ***
#
#
#
# FINAL RUN ON OPTIMIZED ARCHITECTURE
# In the init function of Generic Network.py, here the value of parsed layers is: [{'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'MaxPool'}, {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 6, 'activation': 'ReLU'}, {'layer_type': 'Upsample', 'mode': 'n'}, {'layer_type': 'SkipConnection'}, {'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'ReLU'}, {'layer_type': 'SegmentationHead'}]
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'ReLU'}
# Parsing MBConvNoRes
# Parsing ReLU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: MaxPool, Full Layer: {'layer_type': 'MaxPool'}
# Parsing MaxPool
# Parsed MaxPool without error
# Parsing layer type in generic_network: DenseNetBlock, Full Layer: {'layer_type': 'DenseNetBlock', 'out_channels_coefficient': 6, 'activation': 'ReLU'}
# Parsing DenseNetBlock
# Parsing ReLU
# Parsed DenseNetBlock without error
# Parsing layer type in generic_network: Upsample, Full Layer: {'layer_type': 'Upsample', 'mode': 'n'}
# Parsing Upsample
# Parsed Upsample without error
# Parsing layer type in generic_network: SkipConnection, Full Layer: {'layer_type': 'SkipConnection'}
# Parsing SkipConnection
# Parsed Skip Connection withour error
# Parsing layer type in generic_network: MBConvNoRes, Full Layer: {'layer_type': 'MBConvNoRes', 'expansion_factor': '6', 'activation': 'ReLU'}
# Parsing MBConvNoRes
# Parsing ReLU
# Parsed MBConvNoRes without error
# Parsing layer type in generic_network: SegmentationHead, Full Layer: {'layer_type': 'SegmentationHead'}
# Parsing SegmentationHead
# Parsed SegmentationHead without error
# Architecture is valid, total parameters: 59168
# Running in final loop
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W829 01:47:51.461288947 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W829 01:47:51.471318905 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W829 01:47:51.475129156 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W829 01:47:51.484353889 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | GenericNetwork   | 59.2 K | train
# 1 | loss_fn | FocalLoss        | 0      | train
# 2 | mse     | MeanSquaredError | 0      | train
# -----------------------------------------------------
# 59.2 K    Trainable params
# 0         Non-trainable params
# 59.2 K    Total params
# 0.237     Total estimated model params size (MB)
# 43        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W829 01:59:57.764328371 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W829 01:59:57.772994052 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W829 01:59:57.773877922 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W829 01:59:57.780973244 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.validate()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('val_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_iou          │     0.76731276512146      │
# │         val_loss          │    0.32337212562561035    │
# │          val_mse          │   0.054714202880859375    │
# └───────────────────────────┴───────────────────────────┘
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# Initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# [W829 02:00:06.038712442 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W829 02:00:06.045826261 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W829 02:00:06.046614394 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# [W829 02:00:06.055233109 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:215: Using `DistributedSampler` with the dataloaders. During `trainer.test()`, it is recommended to use `Trainer(devices=1, num_nodes=1)` to ensure each sample/batch gets evaluated exactly once. Otherwise, multi-device settings use `DistributedSampler` that replicates some samples to make sure all devices have same batch size in case of uneven inputs.
# Testing: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_mse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:431: It is recommended to use `self.log('test_iou', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_iou          │    0.7567514181137085     │
# │         test_loss         │    0.32010990381240845    │
# │         test_mse          │    0.05240921303629875    │
# └───────────────────────────┴───────────────────────────┘
# MSE value is 0.05240921303629875
# IoU value is 0.7567514181137085
# num_param value is 59168
# FINAL RUN COMPLETED:
# Training time: 726.6276926994324
# Fitness: 17.01035345751684
# ********
# Saved model weights to Models/OptimizedModelWeights_2024-08-29_01-47-49.pt
# Saved model architecture to Models/OptimizedModelArchitecture_2024-08-29_01-47-49.txt
# Saved entire model (architecture + weights) to Models/OptimizedModelFull_2024-08-29_01-47-49.pt
#
# Final run text file saved: ./logs/tb_logs/checkpoints/Optimized_Architecture_Final_Run_2024-08-29_01-47-49.txt

# %% [markdown]
# ## GUIDE TO CONFIG.INI

# %% [markdown]
# NOTE: most sanity checks are still missing. Be careful please.

# %% [markdown]
# - In the [Mode] section, select the desired mode for pynattas. If both are true, nas will be done first, then ht will be done on the winning architecture of nas. If only ht is true, then tuning will be done on the architecture written in architecture_code under the [NAS] section.
# - max_layers in [NAS] section refers to the maximum size of the chromosomes (aka, maximum number of convolutions-type layers).
# - In the [GA] section, change the parameters for NAS search.
# - In the [Computation] section, be careful about the num_workers value. Currently set to 1 for safety when testing parallelization. In computation, also change the accellerator to either "cpu" or "gpu".

# %% [markdown]
# ## GUIDE TO PARALLELIZATION (currently broken)

# %% [markdown]
# NOTE: Mostly untested.
# - In main.py, change line 54 ("nas_result = pnas.optimizers.ga.ga_optimizer(") to:
#     - nas_result = pnas.optimizers.ga_concurrent.ga_optimizer(" for nas parallelization using a ThreadPoolExecutor
#     - nas_result = pnas.optimizers.ga_concurrent_pp.ga_optimizer(" for nas parallelization using a ProcessPoolExecutor
#
# Currently, it looks like there are issues with ProcessPoolExecutor. Regardless, be careful when selecting num_workers in the config.ini when testing these.

# %% [markdown]
# ## TO ADD NEW BLOCKS

# %% [markdown]
# - in pynattas.blocks add the new block to the related .py file depending on type.
# - in config.ini add the new block as a section with all related parameters. Use "default_" for default values that are used during NAS, and "min_" and "max_" for range values to be used during tuning. Also, update the commented vocabulary at the start for clarity purposes.
# - in pynattas.configuration.vocabulary, update relative vocabularies.
# - in pynattas.classes.generic_network, add the layer construction to the list making sure that the current_layers, current_height, and current_width is calculated correctly.

# %% [markdown]
# ## TO WORK ON NEW DATASET

# %% [markdown]
# - Add dataset to the "data" folder
# - Add compatible datamodule to the "datasets" folder
# - in pynattas.functions.fitness, import the desired datamodule. Also, around line 59, update the datahandling to be compatible with your datamodule. For the ClassificationHead, Make sure the data is resized to 256x256 sized HxW images, that the number of channels passed to the model is correct.
# - change config.ini in the [Dataset] section. "data_path" should point to the dataset, "csv_path" is for a .csv for labels if required. If it's not required, imput None

# %% [markdown]
# ## GUIDE TO LOGS

# %% [markdown]
# Logs are stored in the "logs" folder and in the "lightning_logs" folder. In "logs", you will find:
# - logs about NAS iterations and results in the GA_logs subfolder
# - logs about HT iterations and results in either the GWO_logs or PSO_logs subfolder depending on the selected HT algorithm
# - logs about the final run comprised of the saved checkpoint .ckpt file in the "tb_logs" subfolder, together with all the confusion matrixes generated.

# %% [markdown]
# ## INFERENCE (Coming soon...)
